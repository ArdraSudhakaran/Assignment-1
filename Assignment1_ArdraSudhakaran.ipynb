# %% [markdown]
# # Assignment on Python for Data Science

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1.Read the dataset to python environment

# %%
iris=pd.read_excel(r"C:\Users\vaio\Downloads\iris.xls")
iris
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 2.Display the columns in the dataset

# %%
iris.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# 3.Calculate the mean of each column of the dataset

# %%
iris[['SL','SW','PL','PW']].mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# 4.Check for the null values present in the dataset

# %%
iris.isnull().sum()                   #returns the sum of null values in each column of the dataset
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# 5..Perform meaningful visualizations using the data set.Bring atleast 3 visualizations

# %% [markdown]
# a.Histogram

# %%
# Histogram using matplotlib

plt.figure(figsize=(8,5))
plt.hist(iris['PL'])
plt.title('Distribution of petal length')
plt.xlabel('Petal length')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram using seaborn

sns.histplot(x=iris['SL'])
plt.title('Distribution of sepal length')
plt.show()

# %% [markdown]
# b. Boxplot

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=iris['Classification'],y=iris['PW'])
plt.title('Boxplot of species data')
plt.show()

# %% [markdown]
# c. Scatter plot

# %%
# Scatter plot of sepal length vs sepal width of 3 species


sns.scatterplot(x=iris['SL'],y=iris['SW'],hue=iris['Classification'])
plt.title('Scatter plot')
# Out:
# Text(0.5, 1.0, 'Scatter plot')

# %% [markdown]
# d. Pair plot

# %%
# Pairplot to analyze the relationship between species for all characteristic combinations

sns.pairplot(iris,hue='Classification')
plt.title('Pairplot')
plt.show()
